# %%
# %run ./new_installments.ipynb
# %run ./new_recurrent_spend.ipynb
# %run ./new_transactions.ipynb
# Out:
# Rows generated successfully
# Rows generated successfully
#    fecha_de_cargo          descripcion       categoria       monto  \
# 0      2024-05-17    Credito de nomina  Credito Nomina  500.000000
# 1      2024-06-02    Credito de nomina  Credito Nomina  500.000000
# 2      2024-06-17    Credito de nomina  Credito Nomina  500.000000
# 3      2024-07-02    Credito de nomina  Credito Nomina  500.000000
# 4      2024-07-17    Credito de nomina  Credito Nomina  500.000000
# 5      2024-08-02    Credito de nomina  Credito Nomina  500.000000
# 6      2024-08-17    Credito de nomina  Credito Nomina  500.000000
# 7      2024-09-02    Credito de nomina  Credito Nomina  500.000000
# 8      2024-09-17    Credito de nomina  Credito Nomina  500.000000
# 9      2023-10-29  Celular Samsung A54    Electrónicos  555.555556
# 10     2023-11-29  Celular Samsung A54    Electrónicos  555.555556
# 11     2023-12-29  Celular Samsung A54    Electrónicos  555.555556
# ...

# %%
# %store -r df

# %%
df.to_csv('historial_cargos.csv', encoding='utf-8-sig', index=False)
