# %%
# %run ./all_spend.ipynb
# %run ./new_recurrent_income.ipynb
# Out:
# Rows generated successfully
# Rows generated successfully
# Rows generated successfully
#    fecha_de_cargo   comercio          descripcion          categoria  \
# 0      2023-10-29  Liverpool  Celular Samsung A54       Electrónicos
# 1      2023-11-05  Liverpool  Celular Samsung A54       Electrónicos
# 2      2023-11-12  Liverpool  Celular Samsung A54       Electrónicos
# 3      2023-11-19  Liverpool  Celular Samsung A54       Electrónicos
# 4      2023-11-26  Liverpool  Celular Samsung A54       Electrónicos
# ..            ...        ...                  ...                ...
# 70     2025-04-29                       Minisplit  Electrodomesticos
# 71     2025-05-29                       Minisplit  Electrodomesticos
# 72     2024-10-05
# 73     2024-11-05
# 74     2024-12-05
#
#          monto forma_de_pago realizado_por limite_de_pago  \
# 0   185.185185         LikeU         Aylin     2023-12-01
# 1   185.185185         LikeU         Aylin     2023-12-01
# 2   185.185185         LikeU         Aylin     2023-12-01
# 3   185.185185         LikeU         Aylin     2023-12-31
# 4   185.185185         LikeU         Aylin     2023-12-31
# ..         ...           ...           ...            ...
# 70  375.888889     Liverpool         Aylin     2025-06-17
# 71  375.888889     Liverpool         Aylin     2025-07-18
# 72  133.000000                                 2024-10-05
# 73  133.000000                                 2024-11-05
# 74  133.000000                                 2024-12-05
#
#    deuda_a_plazos_recurrente_o_normal                   comentarios
# 0                              Plazos
# 1                              Plazos
# 2                              Plazos
# 3                              Plazos
# 4                              Plazos
# ..                                ...                           ...
# 70                             Plazos  Aylin lo paga con mi tarjeta
# 71                             Plazos  Aylin lo paga con mi tarjeta
# 72                             Plazos
# 73                             Plazos
# 74                             Plazos
#
# [75 rows x 10 columns]
# Stored 'plazos_df' (DataFrame)
# Rows generated successfully
# Rows generated successfully
# Rows generated successfully
# Rows generated successfully
# Rows generated successfully
#     fecha_de_cargo           descripcion          categoria  monto  \
# 0       2024-04-01              Gasolina           Gasolina    290
# 1       2024-04-08              Gasolina           Gasolina    290
# 2       2024-04-15              Gasolina           Gasolina    290
# 3       2024-04-22              Gasolina           Gasolina    290
# 4       2024-04-29              Gasolina           Gasolina    290
# ..             ...                   ...                ...    ...
# 227     2024-12-30  Afinacion polo plata  Reparaciones auto   2400
# 228     2025-06-30  Afinacion polo plata  Reparaciones auto   2400
# 229     2025-12-30  Afinacion polo plata  Reparaciones auto   2400
# 230     2026-06-30  Afinacion polo plata  Reparaciones auto   2400
# 231     2026-12-30  Afinacion polo plata  Reparaciones auto   2400
#
#     forma_de_pago realizado_por limite_de_pago  \
# 0           LikeU         David     2024-05-01
# 1           LikeU         David     2024-05-01
# 2           LikeU         David     2024-05-31
# 3           LikeU         David     2024-05-31
# 4           LikeU         David     2024-05-31
# ..            ...           ...            ...
# 227      Efectivo         David     2024-12-30
# 228      Efectivo         David     2025-06-30
# 229      Efectivo         David     2025-12-30
# 230      Efectivo         David     2026-06-30
# 231      Efectivo         David     2026-12-30
#
#     deuda_a_plazos_recurrente_o_normal comentarios
# 0                           Recurrente
# 1                           Recurrente
# 2                           Recurrente
# 3                           Recurrente
# 4                           Recurrente
# ..                                 ...         ...
# 227                         Recurrente
# 228                         Recurrente
# 229                         Recurrente
# 230                         Recurrente
# 231                         Recurrente
#
# [232 rows x 9 columns]
# Stored 'recurrentes_df' (DataFrame)
# Stored 'df' (DataFrame)
#         freq fecha_de_ingreso  ingreso_por_evento     cuenta_destino  \
# indice
# 0          0       2024-03-28              500.00           Efectivo
# 1          1       2024-04-04              500.00           Efectivo
# 2          2       2024-04-11              500.00           Efectivo
# 3          3       2024-04-18              500.00           Efectivo
# 4          4       2024-04-25              500.00           Efectivo
# 5          5       2024-05-02              500.00           Efectivo
# 6          6       2024-05-09              500.00           Efectivo
# 7          7       2024-05-16              500.00           Efectivo
# 8          8       2024-05-23              500.00           Efectivo
# 9          9       2024-05-30              500.00           Efectivo
# 10        10       2024-06-06              500.00           Efectivo
# 11        11       2024-06-13              500.00           Efectivo
# 12         0       2024-03-14            22000.12  Banamex Mi Cuenta
# 13         1       2024-03-29            23000.00  Banamex Mi Cuenta
# 14         2       2024-04-14            23000.00  Banamex Mi Cuenta
# 15         3       2024-04-29            23000.00  Banamex Mi Cuenta
# 16         4       2024-05-14            23000.00  Banamex Mi Cuenta
# 17         5       2024-05-29            23000.00  Banamex Mi Cuenta
# 18         6       2024-06-14            23000.00  Banamex Mi Cuenta
# 19         7       2024-06-29            23000.00  Banamex Mi Cuenta
# 20         8       2024-07-14            23000.00  Banamex Mi Cuenta
# 21         9       2024-07-29            23000.00  Banamex Mi Cuenta
# 22        10       2024-08-14            23000.00  Banamex Mi Cuenta
# 23        11       2024-08-29            23000.00  Banamex Mi Cuenta
# 24        12       2024-09-14            23000.00  Banamex Mi Cuenta
# 25        13       2024-09-29            23000.00  Banamex Mi Cuenta
# 26        14       2024-10-14            23000.00  Banamex Mi Cuenta
# 27        15       2024-10-29            23000.00  Banamex Mi Cuenta
# 28        16       2024-11-14            23000.00  Banamex Mi Cuenta
# 29        17       2024-11-29            23000.00  Banamex Mi Cuenta
# 30        18       2024-12-14            23000.00  Banamex Mi Cuenta
# 31        19       2024-12-29            23000.00  Banamex Mi Cuenta
# 32        20       2025-01-14            23000.00  Banamex Mi Cuenta
# 33        21       2025-01-29            23000.00  Banamex Mi Cuenta
# 34        22       2025-02-14            23000.00  Banamex Mi Cuenta
# 35        23       2025-03-01            23000.00  Banamex Mi Cuenta
#
#            descripcion    categoria realizado_por  \
# indice
# 0                 Vita  Recompensas         David
# 1                 Vita  Recompensas         David
# 2                 Vita  Recompensas         David
# 3                 Vita  Recompensas         David
# 4                 Vita  Recompensas         David
# 5                 Vita  Recompensas         David
# 6                 Vita  Recompensas         David
# 7                 Vita  Recompensas         David
# 8                 Vita  Recompensas         David
# 9                 Vita  Recompensas         David
# 10                Vita  Recompensas         David
# 11                Vita  Recompensas         David
# 12      Mi descripcion      Salario         David
# 13      Mi descripcion      Salario         David
# 14      Mi descripcion      Salario         David
# 15      Mi descripcion      Salario         David
# 16      Mi descripcion      Salario         David
# 17      Mi descripcion      Salario         David
# 18      Mi descripcion      Salario         David
# 19      Mi descripcion      Salario         David
# 20      Mi descripcion      Salario         David
# 21      Mi descripcion      Salario         David
# 22      Mi descripcion      Salario         David
# 23      Mi descripcion      Salario         David
# 24      Mi descripcion      Salario         David
# 25      Mi descripcion      Salario         David
# 26      Mi descripcion      Salario         David
# 27      Mi descripcion      Salario         David
# 28      Mi descripcion      Salario         David
# 29      Mi descripcion      Salario         David
# 30      Mi descripcion      Salario         David
# 31      Mi descripcion      Salario         David
# 32      Mi descripcion      Salario         David
# 33      Mi descripcion      Salario         David
# 34      Mi descripcion      Salario         David
# 35      Mi descripcion      Salario         David
#
#        ingreso_recurrente_o_extraoridinario comentarios
# indice
# 0                                Recurrente      Ventas
# 1                                Recurrente      Ventas
# 2                                Recurrente      Ventas
# 3                                Recurrente      Ventas
# 4                                Recurrente      Ventas
# 5                                Recurrente      Ventas
# 6                                Recurrente      Ventas
# 7                                Recurrente      Ventas
# 8                                Recurrente      Ventas
# 9                                Recurrente      Ventas
# 10                               Recurrente      Ventas
# 11                               Recurrente      Ventas
# 12                               Recurrente      Sueldo
# 13                               Recurrente      Sueldo
# 14                               Recurrente      Sueldo
# 15                               Recurrente      Sueldo
# 16                               Recurrente      Sueldo
# 17                               Recurrente      Sueldo
# 18                               Recurrente      Sueldo
# 19                               Recurrente      Sueldo
# 20                               Recurrente      Sueldo
# 21                               Recurrente      Sueldo
# 22                               Recurrente      Sueldo
# 23                               Recurrente      Sueldo
# 24                               Recurrente      Sueldo
# 25                               Recurrente      Sueldo
# 26                               Recurrente      Sueldo
# 27                               Recurrente      Sueldo
# 28                               Recurrente      Sueldo
# 29                               Recurrente      Sueldo
# 30                               Recurrente      Sueldo
# 31                               Recurrente      Sueldo
# 32                               Recurrente      Sueldo
# 33                               Recurrente      Sueldo
# 34                               Recurrente      Sueldo
# 35                               Recurrente      Sueldo
# Stored 'recurrent_incomme_updated' (DataFrame)

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.getOrCreate()

# %%
cargos = spark.read.load("all_spend.csv", delimiter = ",", inferSchema=True, header = True, format = "csv")

# %%
cargos.show(10)
# Out:
# +--------------+--------+-------------------+------------+-----------------+-------------+-------------+-------------+--------------+----------------------------------+
# |fecha_de_cargo|comercio|        descripcion|   categoria|            monto|forma_de_pago|realizado_por|  comentarios|limite_de_pago|deuda_a_plazos_recurrente_o_normal|
# +--------------+--------+-------------------+------------+-----------------+-------------+-------------+-------------+--------------+----------------------------------+
# |    2024-09-30|  Costco|             Costco|    Despensa|          2585.35|       Costco|        David|Dia de madres|    2024-11-04|                            Normal|
# |    2024-09-30|     Heb|       Heb despensa|    Despensa|           604.39|       Costco|         NULL|         NULL|    2024-11-04|                            Normal|
# |    2023-10-29|    NULL|Celular Samsung A54|Electrónicos|185.1851851851852|        LikeU|        Aylin|         NULL|    2023-12-01|                            Plazos|
# |    2023-11-05|    NULL|Celular Samsung A54|Electrónicos|185.1851851851852|        LikeU|        Aylin|         NULL|    2023-12-01|                            Plazos|
# |    2023-11-12|    NULL|Celular Samsung A54|Electrónicos|185.1851851851852|        LikeU|        Aylin|         NULL|    2023-12-01|                            Plazos|
# |    2023-11-19|    NULL|Celular Samsung A54|Electrónicos|185.1851851851852|        LikeU|        Aylin|         NULL|    2023-12-31|                            Plazos|
# |    2023-11-26|    NULL|Celular Samsung A54|Electrónicos|185.1851851851852|        LikeU|        Aylin|         NULL|    2023-12-31|                            Plazos|
# |    2023-12-03|    NULL|Celular Samsung A54|Electrónicos|185.1851851851852|        LikeU|        Aylin|         NULL|    2023-12-31|                            Plazos|
# |    2023-12-10|    NULL|Celular Samsung A54|Electrónicos|185.1851851851852|        LikeU|        Aylin|         NULL|    2023-12-31|                            Plazos|
# |    2023-12-17|    NULL|Celular Samsung A54|Electrónicos|185.1851851851852|        LikeU|        Aylin|         NULL|    2024-01-31|                            Plazos|
# +--------------+--------+-------------------+------------+-----------------+-------------+-------------+-------------+--------------+----------------------------------+
# only showing top 10 rows

# %%
cargos.createOrReplaceTempView("cargos")

# %%
ingresos = spark.read.load("ingresos_recurrentes_detalle.csv", delimiter = ",", inferSchema=True, header = True, format = "csv")

# %%
from pyspark.sql.functions import *

# %%
ingresos = ingresos.filter(col("categoria") == "Salario")

# %%
ingresos.createOrReplaceTempView("ingresos")

# %%
spark.sql("""
        select 
            i.fecha_de_ingreso AS lower_salary_date,
            i2.fecha_de_ingreso AS upper_salary_date,
            i.ingreso_por_evento
          FROM ingresos AS i
          LEFT JOIN ingresos AS i2
            ON i.indice = i2.indice - 1
        
          """).createOrReplaceTempView("wage_date_range")

# %%
spark.table("wage_date_range").show(30)
# Out:
# +-----------------+-----------------+------------------+
# |lower_salary_date|upper_salary_date|ingreso_por_evento|
# +-----------------+-----------------+------------------+
# |       2024-03-14|       2024-03-29|          22000.12|
# |       2024-03-29|       2024-04-14|           23000.0|
# |       2024-04-14|       2024-04-29|           23000.0|
# |       2024-04-29|       2024-05-14|           23000.0|
# |       2024-05-14|       2024-05-29|           23000.0|
# |       2024-05-29|       2024-06-14|           23000.0|
# |       2024-06-14|       2024-06-29|           23000.0|
# |       2024-06-29|       2024-07-14|           23000.0|
# |       2024-07-14|       2024-07-29|           23000.0|
# |       2024-07-29|       2024-08-14|           23000.0|
# |       2024-08-14|       2024-08-29|           23000.0|
# |       2024-08-29|       2024-09-14|           23000.0|
# |       2024-09-14|       2024-09-29|           23000.0|
# |       2024-09-29|       2024-10-14|           23000.0|
# |       2024-10-14|       2024-10-29|           23000.0|
# |       2024-10-29|       2024-11-14|           23000.0|
# |       2024-11-14|       2024-11-29|           23000.0|
# |       2024-11-29|       2024-12-14|           23000.0|
# |       2024-12-14|       2024-12-29|           23000.0|
# |       2024-12-29|       2025-01-14|           23000.0|
# |       2025-01-14|       2025-01-29|           23000.0|
# |       2025-01-29|       2025-02-14|           23000.0|
# |       2025-02-14|       2025-03-01|           23000.0|
# |       2025-03-01|             NULL|           23000.0|
# +-----------------+-----------------+------------------+

# %%
spark.sql("""
        
        SELECT 
          * 
        FROM cargos AS c
        LEFT JOIN wage_date_range AS dates
          WHERE c.limite_de_pago >= dates.lower_salary_date
          AND c.limite_de_pago < dates.upper_salary_date
          
""").createOrReplaceTempView("gastos_ingresos")

# %%
spark.sql("""
        SELECT 
            realizado_por, forma_de_pago, limite_de_pago, lower_salary_date,
            SUM(MONTO) AS Monto_Total
        FROM gastos_ingresos
        GROUP BY
          realizado_por, forma_de_pago, limite_de_pago, lower_salary_date
          """).show(50)
# Out:
# +-------------+--------------+--------------+-----------------+-----------------+
# |realizado_por| forma_de_pago|limite_de_pago|lower_salary_date|      Monto_Total|
# +-------------+--------------+--------------+-----------------+-----------------+
# |        David|      Efectivo|    2024-07-12|       2024-06-29|            120.0|
# |        David|   Hey Credito|    2024-10-31|       2024-10-29|           1947.0|
# |        Aylin|      Efectivo|    2025-01-30|       2025-01-29|           1500.0|
# |        Aylin|         LikeU|    2024-10-31|       2024-10-29|2340.740740740741|
# |        Aylin|     Liverpool|    2025-01-17|       2025-01-14|375.8888888888889|
# |        David|      Efectivo|    2024-08-23|       2024-08-14|            120.0|
# |        Aylin|      Efectivo|    2024-05-30|       2024-05-29|           1500.0|
# |        David|      Efectivo|    2024-06-28|       2024-06-14|            120.0|
# |        David|         LikeU|    2024-12-01|       2024-11-29|           1450.0|
# |        Aylin|         LikeU|    2024-12-31|       2024-12-29|           1600.0|
# |        David|Crédito Nomina|    2024-06-17|       2024-06-14|            500.0|
# |        Aylin|      Efectivo|    2024-10-30|       2024-10-29|           1500.0|
# |        Aylin|      Efectivo|    2024-04-30|       2024-04-29|           1500.0|
# |        Aylin|      Efectivo|    2024-06-30|       2024-06-29|           1500.0|
# |        Aylin|         LikeU|    2024-07-01|       2024-06-29|2740.740740740741|
# |        David|      Efectivo|    2024-10-30|       2024-10-29|           2000.0|
# |        David|      Efectivo|    2024-11-24|       2024-11-14|            150.0|
# |        Aylin|         LikeU|    2024-12-01|       2024-11-29|2740.740740740741|
# |        David|      Efectivo|    2025-01-24|       2025-01-14|            150.0|
# |        David|      Efectivo|    2024-08-24|       2024-08-14|            150.0|
# |        David|      Efectivo|    2024-12-24|       2024-12-14|            150.0|
# |        David|      Efectivo|    2024-07-26|       2024-07-14|            120.0|
# |        David|Crédito Nomina|    2024-09-17|       2024-09-14|            500.0|
# |        Aylin|         LikeU|    2024-10-01|       2024-09-29|2340.740740740741|
# |         NULL|          NULL|    2024-12-05|       2024-11-29|            133.0|
# |        Aylin|         LikeU|    2024-05-31|       2024-05-29|2525.925925925926|
# |        David|      Efectivo|    2024-04-30|       2024-04-29|           2000.0|
# |        David|         LikeU|    2024-10-01|       2024-09-29|           1160.0|
# |        David|Crédito Nomina|    2024-05-17|       2024-05-14|            500.0|
# |        Aylin|     Liverpool|    2024-11-17|       2024-11-14|375.8888888888889|
# |        Aylin|      Efectivo|    2024-12-30|       2024-12-29|           1500.0|
# |        David|      Efectivo|    2024-10-24|       2024-10-14|            150.0|
# |        David|   Hey Credito|    2024-07-01|       2024-06-29|           1947.0|
# |        David|      Efectivo|    2024-05-17|       2024-05-14|            120.0|
# |        David|      Efectivo|    2024-08-30|       2024-08-29|           2000.0|
# |        David|      Efectivo|    2024-05-31|       2024-05-29|            120.0|
# |        David|      Efectivo|    2024-07-24|       2024-07-14|            150.0|
# |        David|         LikeU|    2024-10-31|       2024-10-29|           1160.0|
# |        Aylin|      Efectivo|    2024-07-30|       2024-07-29|           1500.0|
# |         NULL|        Costco|    2024-11-04|       2024-10-29|           604.39|
# |        David|      Efectivo|    2024-04-24|       2024-04-14|            150.0|
# |        David|         LikeU|    2024-07-01|       2024-06-29|           1450.0|
# |        David|         LikeU|    2024-12-31|       2024-12-29|           1160.0|
# |        Aylin|         LikeU|    2025-01-31|       2025-01-29|           1600.0|
# |        David|   Hey Credito|    2024-08-31|       2024-08-29|           1947.0|
# |        David|      Efectivo|    2024-06-24|       2024-06-14|            150.0|
# |        Aylin|         LikeU|    2024-07-31|       2024-07-29|2340.740740740741|
# |        David|      Efectivo|    2024-05-30|       2024-05-29|           2000.0|
# |        David|      Efectivo|    2024-12-30|       2024-12-29|           4400.0|
# |        David|      Efectivo|    2024-07-30|       2024-07-29|           2000.0|
# +-------------+--------------+--------------+-----------------+-----------------+
# only showing top 50 rows
