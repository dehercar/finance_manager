# %%
import pandas as pd

# %%
excel_dbfs_path = f"./david_finance.xlsx"
sheet_name = f"nueva_deuda_a_plazos"

# %%
dfp = pd.read_excel(excel_dbfs_path, engine = "openpyxl", sheet_name = sheet_name, dtype = {"monto_total_deuda":'float'})

# %%
tdc_df = pd.read_excel(excel_dbfs_path, engine = "openpyxl", sheet_name = "tarjetas_de_credito")

# %%
display(tdc_df.loc[tdc_df["payment_method"] == "LikeU"]["dia_de_corte"].values[0])
display(tdc_df.loc[tdc_df["payment_method"] == "LikeU"]["plazo_para_pagar"].values[0])
# si el dia del cargo es despues del corte sumamos el plazo para pagar 
# de lo contrario, es decir, si el dia de cargo es inferior al dia de corte, construimos el dia de pago sumando 1 mes al mes actual
# Out:
# 12
# 19

# %%
class InstallmentsCreator:
    def __init__(self, df: pd.DataFrame):
        self.empty_installments_df = pd.DataFrame(
                        columns=['fecha_de_cargo' ,
                                'descripcion', 
                                'categoria', 
                                'monto', 
                                'forma_de_pago', 
                                'realizado_por', 
                                'limite_de_pago', 
                                'deuda_a_plazos_recurrente_o_normal', 
                                'comentarios'
                                ])

        self.tdc_df = pd.read_excel(excel_dbfs_path, engine = "openpyxl", sheet_name = "tarjetas_de_credito")
        self.condition_blank_comment = lambda text: text if text == text else ""
        self.df = df
        
        
    def get_pay_deadlines(self, row, date_range_i_row):
        try:
            dia_de_corte = self.tdc_df.loc[tdc_df["payment_method"] == row["forma_de_pago"]]["dia_de_corte"].values[0]
            plazo_para_pagar = self.tdc_df.loc[tdc_df["payment_method"] == row["forma_de_pago"]]["plazo_para_pagar"].values[0]
            return [
                pd.to_datetime(f"{date.year}-{date.month}-{dia_de_corte}", format = "%Y-%m-%d") + pd.DateOffset(days= plazo_para_pagar, months=1) 
                if date.day > dia_de_corte 
                else pd.to_datetime(f"{date.year}-{date.month}-{dia_de_corte}", format = "%Y-%m-%d") + pd.DateOffset(days= plazo_para_pagar) 
                for date in date_range_i_row
            ]
        except IndexError:
            return date_range_i_row


    def create_nthly_installments(self,row, date_range_i_row):
        return  pd.DataFrame(
            data={'fecha_de_cargo': date_range_i_row,
                    'descripcion': self.condition_blank_comment(row["descripcion"]), 
                    'categoria': row["categoria"], 
                    'monto': row["monto_total_deuda"] / row["numero_de_plazos"], 
                    'forma_de_pago': row["forma_de_pago"], 
                    'realizado_por': row["realizado_por"], 
                    'limite_de_pago': self.get_pay_deadlines(row, date_range_i_row), 
                    'deuda_a_plazos_recurrente_o_normal': "Plazos", 
                    'comentarios': self.condition_blank_comment(row["comentarios"])
                    }
                )

    
    def create_monthly_date_range(self, row):
        return  pd.date_range(
                    start = f"{row['fecha_de_inicio'].year}-{row['fecha_de_inicio'].month}-01", 
                    periods = row["numero_de_plazos"], 
                    freq = "MS"
                ) + pd.DateOffset(days=row['fecha_de_inicio'].day - 1)

    def create_monthly_installments(self, frequency_desc_column: str = "frecuencia_de_pago", frecuency_desc_value: str = "mensual"):
        df = self.df.loc[self.df[frequency_desc_column] == frecuency_desc_value].copy()
        if len(df) > 0:
            df_new_installments = self.empty_installments_df
            for _,row in df.iterrows():
                date_range_i_row = self.create_monthly_date_range(row)
                if len(df_new_installments) == 0:
                    df_new_installments = self.create_nthly_installments(row, date_range_i_row)
                else:
                    df_new_installments = (
                        pd.concat([
                            df_new_installments,
                            self.create_nthly_installments(row, date_range_i_row)
                        ],
                            ignore_index=True
                        )
                    ) 
            print("Rows generated successfully")
            return df_new_installments
        else:
            return None
    
        
    def create_semimonthly_date_range(self, row):
        return pd.date_range(
                    start = f"{row['fecha_de_inicio']}", 
                    periods = row["numero_de_plazos"], 
                    freq = "SME"
                ) + pd.DateOffset(days=row["dias_de_margen"])
    
    def create_semimonthly_installments(self, frequency_desc_column: str = "frecuencia_de_pago", frecuency_desc_value: str = "quincenal"):
        df = self.df.loc[self.df[frequency_desc_column] == frecuency_desc_value].copy()
        if len(df) > 0:
            df_new_installments = self.empty_installments_df
            for _,row in df.iterrows():
                date_range_i_row = self.create_semimonthly_date_range(row)
                if len(df_new_installments) == 0:
                    df_new_installments = self.create_nthly_installments(row, date_range_i_row)
                else:
                    df_new_installments = (
                        pd.concat([
                            df_new_installments,
                            self.create_nthly_installments(row, date_range_i_row)
                        ],
                            ignore_index=True
                        )
                    ) 
            print("Rows generated successfully")
            return df_new_installments
        else:
            return None
        
    def create_bimonthly_date_range(self, row):
        return pd.date_range(
                start = pd.to_datetime(f"{row['fecha_de_inicio'].year}-{row['fecha_de_inicio'].month}-01", format="%Y-%m-%d"), 
                periods = row['numero_de_plazos'], 
                freq = "2MS"
                ) + pd.DateOffset(days=row['fecha_de_inicio'].day - 1)
    
    def create_bimonthly_installments(self, frequency_desc_column: str = "frecuencia_de_pago", frecuency_desc_value: str = "bimestral"):
        df = self.df.loc[self.df[frequency_desc_column] == frecuency_desc_value].copy()
        if len(df) > 0:
            df_new_installments = self.empty_installments_df
            for _,row in df.iterrows():
                date_range_i_row = self.create_bimonthly_date_range(row)
                if len(df_new_installments) == 0:
                    df_new_installments = self.create_nthly_installments(row, date_range_i_row)
                else:
                    df_new_installments = (
                        pd.concat([
                            df_new_installments,
                            self.create_nthly_installments(row, date_range_i_row)
                        ],
                            ignore_index=True
                        )
                    ) 
            print("Rows generated successfully")
            return df_new_installments
        else:
            return None
        
    def create_weekly_date_range(self, row):
        return pd.date_range(start = row['fecha_de_inicio'], periods = row['numero_de_plazos'], freq = "7D") + pd.DateOffset(days=row['dias_de_margen'])
    
    def create_weekly_installments(self, frequency_desc_column: str = "frecuencia_de_pago", frecuency_desc_value: str = "semanal"):
        df = self.df.loc[self.df[frequency_desc_column] == frecuency_desc_value].copy()
        if len(df) > 0:
            df_new_installments = self.empty_installments_df
            for _,row in df.iterrows():
                date_range_i_row = self.create_weekly_date_range(row)
                if len(df_new_installments) == 0:
                    df_new_installments = self.create_nthly_installments(row, date_range_i_row)
                else:
                    df_new_installments = (
                        pd.concat([
                            df_new_installments,
                            self.create_nthly_installments(row, date_range_i_row)
                        ],
                            ignore_index=True
                        )
                    ) 
            print("Rows generated successfully")
            return df_new_installments
        else:
            return None
        
    def pdconcat_wise(self, base_df: pd.DataFrame, concat_df: pd.DataFrame):
        if len(base_df) > 0:
            return pd.concat(
                        [
                            base_df,
                            concat_df
                        ],
                            ignore_index=True
                    )
        else:
            return concat_df

    def create_all_installments(self):
        df_installments_cum = self.empty_installments_df
        df_installments_cum = self.pdconcat_wise(df_installments_cum, self.create_monthly_installments())
        df_installments_cum = self.pdconcat_wise(df_installments_cum, self.create_semimonthly_installments())
        df_installments_cum = self.pdconcat_wise(df_installments_cum, self.create_bimonthly_installments()) 
        df_installments_cum = self.pdconcat_wise(df_installments_cum, self.create_weekly_installments())
        return df_installments_cum

# %%
installments_creator = InstallmentsCreator(dfp)

# %%
installments_creator.df
# Out:
#   fecha_de_transaccion frecuencia_de_pago fecha_de_inicio  numero_de_plazos  \
# 0           2024-04-28            mensual      2024-04-28                12
# 1           2024-04-30            mensual      2024-04-30                12
# 2           2024-05-04          quincenal      2024-05-05                12
# 3           2024-05-04          bimestral      2024-05-14                12
# 4           2024-05-04            semanal      2024-05-14                24
# 5           2024-05-04            mensual      2024-05-14                12
# 6           2024-05-04            mensual      2024-05-14                12
#
#    dias_de_margen  monto_total_deuda   forma_de_pago            descripcion  \
# 0               0            12000.0     Hey Credito     Descripcion de gim
# 1               0           120000.0     Hey Credito  Description impuestos
# 2               2              146.0  Crédito Nomina  Credito nomina afirme
# 3               0             5000.0     Hey Credito             Recibo Gas
# 4               0            10000.0           LikeU                    NaN
# 5               0            13000.0       Liverpool                 Laptop
# 6               0            13000.0       Liverpool                 Laptop
#
#         categoria realizado_por                  comentarios
# 0             Gym         David            Comentario de gym
# 1       Impuestos         David      Comentario de Impuestos
# 2  Credito Nomina         David            Comentario nomina
# 3       Servicios         David                          NaN
# 4   Arrendamiento         David                          NaN
# 5   Arrendamiento         Wendy                          NaN
# 6   Arrendamiento         David  Registro por deuda de wendy

# %%
df_all_installments = installments_creator.create_all_installments()
display(df_all_installments)
# Out:
# Rows generated successfully
# Rows generated successfully
# Rows generated successfully
# Rows generated successfully
#    fecha_de_cargo         descripcion      categoria        monto  \
# 0      2024-04-28  Descripcion de gim            Gym  1000.000000
# 1      2024-05-28  Descripcion de gim            Gym  1000.000000
# 2      2024-06-28  Descripcion de gim            Gym  1000.000000
# 3      2024-07-28  Descripcion de gim            Gym  1000.000000
# 4      2024-08-28  Descripcion de gim            Gym  1000.000000
# ..            ...                 ...            ...          ...
# 91     2024-09-24                      Arrendamiento   416.666667
# 92     2024-10-01                      Arrendamiento   416.666667
# 93     2024-10-08                      Arrendamiento   416.666667
# 94     2024-10-15                      Arrendamiento   416.666667
# 95     2024-10-22                      Arrendamiento   416.666667
#
#    forma_de_pago realizado_por limite_de_pago  \
# 0    Hey Credito         David     2024-05-31
# 1    Hey Credito         David     2024-07-01
# 2    Hey Credito         David     2024-07-31
# 3    Hey Credito         David     2024-08-31
# 4    Hey Credito         David     2024-10-01
# ..           ...           ...            ...
# 91         LikeU         David     2024-10-31
# 92         LikeU         David     2024-10-31
# 93         LikeU         David     2024-10-31
# 94         LikeU         David     2024-12-01
# 95         LikeU         David     2024-12-01
#
#    deuda_a_plazos_recurrente_o_normal        comentarios
# 0                              Plazos  Comentario de gym
# 1                              Plazos  Comentario de gym
# 2                              Plazos  Comentario de gym
# 3                              Plazos  Comentario de gym
# 4                              Plazos  Comentario de gym
# ..                                ...                ...
# 91                             Plazos
# 92                             Plazos
# 93                             Plazos
# 94                             Plazos
# 95                             Plazos
#
# [96 rows x 9 columns]

# %%
df_new_semimonthly_installments = installments_creator.create_semimonthly_installments()
display(df_new_semimonthly_installments)
# Out:
# Rows generated successfully
#    fecha_de_cargo            descripcion       categoria      monto  \
# 0      2024-05-17  Credito nomina afirme  Credito Nomina  12.166667
# 1      2024-06-02  Credito nomina afirme  Credito Nomina  12.166667
# 2      2024-06-17  Credito nomina afirme  Credito Nomina  12.166667
# 3      2024-07-02  Credito nomina afirme  Credito Nomina  12.166667
# 4      2024-07-17  Credito nomina afirme  Credito Nomina  12.166667
# 5      2024-08-02  Credito nomina afirme  Credito Nomina  12.166667
# 6      2024-08-17  Credito nomina afirme  Credito Nomina  12.166667
# 7      2024-09-02  Credito nomina afirme  Credito Nomina  12.166667
# 8      2024-09-17  Credito nomina afirme  Credito Nomina  12.166667
# 9      2024-10-02  Credito nomina afirme  Credito Nomina  12.166667
# 10     2024-10-17  Credito nomina afirme  Credito Nomina  12.166667
# 11     2024-11-02  Credito nomina afirme  Credito Nomina  12.166667
#
#      forma_de_pago realizado_por limite_de_pago  \
# 0   Crédito Nomina         David     2024-05-17
# 1   Crédito Nomina         David     2024-06-02
# 2   Crédito Nomina         David     2024-06-17
# 3   Crédito Nomina         David     2024-07-02
# 4   Crédito Nomina         David     2024-07-17
# 5   Crédito Nomina         David     2024-08-02
# 6   Crédito Nomina         David     2024-08-17
# 7   Crédito Nomina         David     2024-09-02
# 8   Crédito Nomina         David     2024-09-17
# 9   Crédito Nomina         David     2024-10-02
# 10  Crédito Nomina         David     2024-10-17
# 11  Crédito Nomina         David     2024-11-02
#
#    deuda_a_plazos_recurrente_o_normal        comentarios
# 0                              Plazos  Comentario nomina
# 1                              Plazos  Comentario nomina
# 2                              Plazos  Comentario nomina
# 3                              Plazos  Comentario nomina
# 4                              Plazos  Comentario nomina
# 5                              Plazos  Comentario nomina
# 6                              Plazos  Comentario nomina
# 7                              Plazos  Comentario nomina
# 8                              Plazos  Comentario nomina
# 9                              Plazos  Comentario nomina
# 10                             Plazos  Comentario nomina
# 11                             Plazos  Comentario nomina

# %%
df_new_bimonthly_installments = installments_creator.create_bimonthly_installments() 
display(df_new_bimonthly_installments)
# Out:
# Rows generated successfully
#    fecha_de_cargo descripcion  categoria       monto forma_de_pago  \
# 0      2024-05-14  Recibo Gas  Servicios  416.666667   Hey Credito
# 1      2024-07-14  Recibo Gas  Servicios  416.666667   Hey Credito
# 2      2024-09-14  Recibo Gas  Servicios  416.666667   Hey Credito
# 3      2024-11-14  Recibo Gas  Servicios  416.666667   Hey Credito
# 4      2025-01-14  Recibo Gas  Servicios  416.666667   Hey Credito
# 5      2025-03-14  Recibo Gas  Servicios  416.666667   Hey Credito
# 6      2025-05-14  Recibo Gas  Servicios  416.666667   Hey Credito
# 7      2025-07-14  Recibo Gas  Servicios  416.666667   Hey Credito
# 8      2025-09-14  Recibo Gas  Servicios  416.666667   Hey Credito
# 9      2025-11-14  Recibo Gas  Servicios  416.666667   Hey Credito
# 10     2026-01-14  Recibo Gas  Servicios  416.666667   Hey Credito
# 11     2026-03-14  Recibo Gas  Servicios  416.666667   Hey Credito
#
#    realizado_por limite_de_pago deuda_a_plazos_recurrente_o_normal comentarios
# 0          David     2024-07-01                             Plazos
# 1          David     2024-08-31                             Plazos
# 2          David     2024-10-31                             Plazos
# 3          David     2024-12-31                             Plazos
# 4          David     2025-03-03                             Plazos
# 5          David     2025-05-01                             Plazos
# 6          David     2025-07-01                             Plazos
# 7          David     2025-08-31                             Plazos
# 8          David     2025-10-31                             Plazos
# 9          David     2025-12-31                             Plazos
# 10         David     2026-03-03                             Plazos
# 11         David     2026-05-01                             Plazos

# %%
df_new_weekly_installments = installments_creator.create_weekly_installments() 
display(df_new_weekly_installments)
# Out:
# Rows generated successfully
#    fecha_de_cargo descripcion      categoria       monto forma_de_pago  \
# 0      2024-05-14              Arrendamiento  416.666667         LikeU
# 1      2024-05-21              Arrendamiento  416.666667         LikeU
# 2      2024-05-28              Arrendamiento  416.666667         LikeU
# 3      2024-06-04              Arrendamiento  416.666667         LikeU
# 4      2024-06-11              Arrendamiento  416.666667         LikeU
# 5      2024-06-18              Arrendamiento  416.666667         LikeU
# 6      2024-06-25              Arrendamiento  416.666667         LikeU
# 7      2024-07-02              Arrendamiento  416.666667         LikeU
# 8      2024-07-09              Arrendamiento  416.666667         LikeU
# 9      2024-07-16              Arrendamiento  416.666667         LikeU
# 10     2024-07-23              Arrendamiento  416.666667         LikeU
# 11     2024-07-30              Arrendamiento  416.666667         LikeU
# 12     2024-08-06              Arrendamiento  416.666667         LikeU
# 13     2024-08-13              Arrendamiento  416.666667         LikeU
# 14     2024-08-20              Arrendamiento  416.666667         LikeU
# 15     2024-08-27              Arrendamiento  416.666667         LikeU
# 16     2024-09-03              Arrendamiento  416.666667         LikeU
# 17     2024-09-10              Arrendamiento  416.666667         LikeU
# 18     2024-09-17              Arrendamiento  416.666667         LikeU
# 19     2024-09-24              Arrendamiento  416.666667         LikeU
# 20     2024-10-01              Arrendamiento  416.666667         LikeU
# 21     2024-10-08              Arrendamiento  416.666667         LikeU
# 22     2024-10-15              Arrendamiento  416.666667         LikeU
# 23     2024-10-22              Arrendamiento  416.666667         LikeU
#
#    realizado_por limite_de_pago deuda_a_plazos_recurrente_o_normal comentarios
# 0          David     2024-07-01                             Plazos
# 1          David     2024-07-01                             Plazos
# 2          David     2024-07-01                             Plazos
# 3          David     2024-07-01                             Plazos
# 4          David     2024-07-01                             Plazos
# 5          David     2024-07-31                             Plazos
# 6          David     2024-07-31                             Plazos
# 7          David     2024-07-31                             Plazos
# 8          David     2024-07-31                             Plazos
# 9          David     2024-08-31                             Plazos
# 10         David     2024-08-31                             Plazos
# 11         David     2024-08-31                             Plazos
# 12         David     2024-08-31                             Plazos
# 13         David     2024-10-01                             Plazos
# 14         David     2024-10-01                             Plazos
# 15         David     2024-10-01                             Plazos
# 16         David     2024-10-01                             Plazos
# 17         David     2024-10-01                             Plazos
# 18         David     2024-10-31                             Plazos
# 19         David     2024-10-31                             Plazos
# 20         David     2024-10-31                             Plazos
# 21         David     2024-10-31                             Plazos
# 22         David     2024-12-01                             Plazos
# 23         David     2024-12-01                             Plazos
